# %% [markdown]
# # Dataverse API Experiments - Part 1
#
# An Interactive Notebook by Tiffany Chan (University of Victoria Libraries)
# tjychan@uvic.ca

# %% [markdown]
# ## Searching Scholars Portal (Search API)
#
# We'll use the [search API](https://guides.dataverse.org/en/latest/api/search.html) to explore Scholars Portal with a simple search. Note that we're passing two parameters for our search:
#
# 1. **q**: this is the keyword we're searching. In our example, this is "trees."
# 2. **per_page**: the maximum number of results we want to return. If this is blank, Dataverse defaults to 10. In our example, this is 5. (Note: this is an integer and not a string).
#
# The parameters are declared in a dictionary: "a list of key-value pairs within braces" (from the [Python documentation])(https://docs.python.org/3/library/stdtypes.html#dict). For example, the first pair consists of a key ('q') and a value of 'trees'.

# %%
search_params = {
    'q': 'trees',
    'per_page': 5 
}

# %% [markdown]
# Now we execute the search using Python's requests library.

# %%
import requests
import json

search_url = 'https://dataverse.scholarsportal.info/api/search'

# Get the first 5 results for a keyword search for "trees"
resp = requests.get(search_url, params=search_params)

# Print the search results with indents so it looks neater
results = resp.json()['data']['items']
print(json.dumps(results, indent=4))
# Out:
# See these results in your browser at https://dataverse.scholarsportal.info/api/search?q=trees&per_page=5
# [
#     {
#         "name": "Data from: Time to get moving: assisted gene flow of forest trees",
#         "type": "dataset",
#         "url": "https://doi.org/10.5683/SP2/BQBI7S",
#         "global_id": "doi:10.5683/SP2/BQBI7S",
#         "description": "Abstract Geographic variation in trees has been investigated since the mid-18th century. Similar patterns of clinal variation have been observed along latitudinal and elevational gradients in common garden experiments for many temperate and boreal species. These studies convinced forest managers that a \u2018local is best\u2019 seed source policy was usually safest for reforestation. In recent decades, experimental design, phenotyping methods, climatic data and statistical analyses have improved greatly and refined but not radically changed knowledge of clines. The maintenance of local adaptation despite high gene flow suggests selection for local adaptation to climate is strong. Concerns over maladaptation resulting from climate change have motivated many new genecological and population genomics studies; however, few jurisdictions have implemented assisted gene flow (AGF), the translocation of pre-adapted individuals to facilitate adaptation of planted forests to climate change. Here, we provide evidence that temperate tree species show clines along climatic gradients sufficiently similar for average patterns or climate models to guide AGF in the absence of species-specific knowledge. Composite provenancing of multiple seed sources can be used to increase diversity and buffer against future climate uncertainty. New knowledge will continue to refine and improve AGF as climates warm further.",
#         "published_at": "2021-05-19T20:47:09Z",
#         "publisher": "UBC Dryad2Dataverse",
#         "citationHtml": "Aitken, Sally N.; Bemmels, Jordan B., 2015, \"Data from: Time to get moving: assisted gene flow of forest trees\", <a href=\"https://doi.org/10.5683/SP2/BQBI7S\" target=\"_blank\">https://doi.org/10.5683/SP2/BQBI7S</a>, Scholars Portal Dataverse, V1, UNF:6:4cq8ZwHm3TIa00EuZeywIw== [fileUNF]",
#         "identifier_of_dataverse": "UBC_DRYAD",
#         "name_of_dataverse": "UBC Dryad2Dataverse",
#         "citation": "Aitken, Sally N.; Bemmels, Jordan B., 2015, \"Data from: Time to get moving: assisted gene flow of forest trees\", https://doi.org/10.5683/SP2/BQBI7S, Scholars Portal Dataverse, V1, UNF:6:4cq8ZwHm3TIa00EuZeywIw== [fileUNF]",
#         "storageIdentifier": "s3://10.5683/SP2/BQBI7S",
#         "keywords": [
#             "Picea sitchensis",
#             "Pinus contorta",
#             "Pinus albicaulis",
#             "Populus trichocarpa",
#             "Alnus rubra",
#             "Pseudotsuga menziesii",
#             "forest policy",
#             "provenance",
#             "Pinus ponderosa",
#             "Thuja plicata",
#             "Pinus monticola",
#             "Tsuga heterophylla",
#             "assisted migration",
#             "genetic clines",
#             "temperate species",
#             "Abies grandis",
#             "Abies procera",
#             "Abies concolor",
#             "Quercus garryana",
#             "Picea engelmannii",
#             "Pinus attenuata",
#             "Abies lasiocarpa",
#             "Cornus nuttallii",
#             "Ecological Genetics",
#             "Picea pungens"
#         ],
#         "subjects": [
#             "Other"
#         ],
#         "fileCount": 2,
#         "versionId": 9714,
#         "versionState": "RELEASED",
#         "majorVersion": 1,
#         "minorVersion": 0,
#         "createdAt": "2021-04-07T19:36:40Z",
#         "updatedAt": "2021-11-30T02:13:23Z",
#         "contacts": [
#             {
#                 "name": "UBC Library Research Data Team",
#                 "affiliation": ""
#             }
#         ],
#         "publications": [
#             {
#                 "citation": "Article",
#                 "url": "https://doi.org/10.1111/eva.12293"
#             }
#         ],
#         "geographicCoverage": [
#             {
#                 "other": "Western North America,"
#             }
#         ],
#         "authors": [
#             "Aitken, Sally N.",
#             "Bemmels, Jordan B."
#         ]
#     },
#     {
#         "name": "Data from: Climatic change only stimulated growth for trees under weak competition in central boreal forests",
#         "type": "dataset",
#         "url": "https://doi.org/10.5683/SP2/LZMAUF",
#         "global_id": "doi:10.5683/SP2/LZMAUF",
#         "description": "Abstract 1. Global change ecologists have often used trees under weak competition (e.g., dominant/codominant trees) to examine relationships between climatic change and tree growth. Scaling up these results to a forest relies on the assumption that the climatic change-tree growth relationship is not affected by tree-level competition. 2. Using permanent sample plot data from the central Canadian boreal region where warming did not result in water deficit, we tested the above-mentioned assumption by looking at whether the relationship between climatic change and tree growth varied with tree-level competition, which was quantified using a modified Hegyi competition index. 3. We found that tree growth increased over time for trees under weak competition, but decreased for those under strong competition. The divergent temporal trends among trees under different levels of competition led to a non-significant change in growth for our study plots. Growth increased with regional warming, atmospheric [CO2] and water availability for trees under weak competition, but not for those under strong competition. 4. Synthesis. Our results suggest that upscaling the growth responses of dominant/codominant trees to climate change to a forest or a region can lead to biased estimates. Tree-level competition should be taken into account when expressing climatic change and tree growth relationships.",
#         "published_at": "2021-05-19T23:14:35Z",
#         "publisher": "UBC Dryad2Dataverse",
#         "citationHtml": "Luo, Yong; McIntire, Eliot J. B.; Boivenue, Celine; Nikiema, Paul P.; Chen, Han H. Y., 2019, \"Data from: Climatic change only stimulated growth for trees under weak competition in central boreal forests\", <a href=\"https://doi.org/10.5683/SP2/LZMAUF\" target=\"_blank\">https://doi.org/10.5683/SP2/LZMAUF</a>, Scholars Portal Dataverse, V1",
#         "identifier_of_dataverse": "UBC_DRYAD",
#         "name_of_dataverse": "UBC Dryad2Dataverse",
#         "citation": "Luo, Yong; McIntire, Eliot J. B.; Boivenue, Celine; Nikiema, Paul P.; Chen, Han H. Y., 2019, \"Data from: Climatic change only stimulated growth for trees under weak competition in central boreal forests\", https://doi.org/10.5683/SP2/LZMAUF, Scholars Portal Dataverse, V1",
#         "storageIdentifier": "s3://10.5683/SP2/LZMAUF",
#         "keywords": [
#             "rising atmospheric CO2",
#             "1986-2011",
#             "boreal forests"
#         ],
#         "subjects": [
#             "Other"
#         ],
#         "fileCount": 2,
#         "versionId": 9306,
#         "versionState": "RELEASED",
#         "majorVersion": 1,
#         "minorVersion": 0,
#         "createdAt": "2021-04-07T16:09:57Z",
#         "updatedAt": "2021-11-29T19:44:45Z",
#         "contacts": [
#             {
#                 "name": "Luo, Yong",
#                 "affiliation": "Lakehead University"
#             },
#             {
#                 "name": "UBC Library Research Data Team",
#                 "affiliation": "Lakehead University"
#             }
#         ],
#         "publications": [
#             {
#                 "citation": "Article",
#                 "url": "https://doi.org/10.1111/1365-2745.13228"
#             }
#         ],
#         "geographicCoverage": [
#             {
#                 "other": "Canada,"
#             },
#             {
#                 "other": "Manitoba,"
#             }
#         ],
#         "authors": [
#             "Luo, Yong",
#             "McIntire, Eliot J. B.",
#             "Boivenue, Celine",
#             "Nikiema, Paul P.",
#             "Chen, Han H. Y."
#         ]
#     },
#     {
#         "name": "Port Hood Tree Survival - 2019",
#         "type": "dataset",
#         "url": "https://doi.org/10.5683/SP2/LPJOBI",
#         "global_id": "doi:10.5683/SP2/LPJOBI",
#         "description": "This dataset contains the survival data for two biomass tree crops (PO = Hybrid Poplar; WW = willow) at the end of the growing season in the year the crop were established (2019). Each crop was treated with one of four soil amendment treatments (CT = untreated control; DG = liquid anaerobic digestate; PS = pulp-mill sludge; SE = seaweed extract). Hybrid Poplar and Willow cuttings were planted at 16,250 plants/ha. Measurement units: % of trees planted in summer still surviving in the fall.",
#         "published_at": "2021-06-24T14:12:40Z",
#         "publisher": "BioMass Canada Project 6 - Purpose-Grown Biomass Crops: Efficient Production, Yield Modelling and Real-world Verification",
#         "citationHtml": "Vessey, J Kevin, 2021, \"Port Hood Tree Survival - 2019\", <a href=\"https://doi.org/10.5683/SP2/LPJOBI\" target=\"_blank\">https://doi.org/10.5683/SP2/LPJOBI</a>, Scholars Portal Dataverse, V1, UNF:6:NUVDiOmr2IfU+8AlXKcpDA== [fileUNF]",
#         "identifier_of_dataverse": "BioMass_Canada_Project_6",
#         "name_of_dataverse": "BioMass Canada Project 6 - Purpose-Grown Biomass Crops: Efficient Production, Yield Modelling and Real-world Verification",
#         "citation": "Vessey, J Kevin, 2021, \"Port Hood Tree Survival - 2019\", https://doi.org/10.5683/SP2/LPJOBI, Scholars Portal Dataverse, V1, UNF:6:NUVDiOmr2IfU+8AlXKcpDA== [fileUNF]",
#         "storageIdentifier": "s3://10.5683/SP2/LPJOBI",
#         "keywords": [
#             "biomass tree crops, survival, coppiced Hybrid Poplar, coppiced Willow, soil amendments"
#         ],
#         "subjects": [
#             "Agricultural Sciences"
#         ],
#         "fileCount": 1,
#         "versionId": 10267,
#         "versionState": "RELEASED",
#         "majorVersion": 1,
#         "minorVersion": 0,
#         "createdAt": "2021-06-24T13:37:48Z",
#         "updatedAt": "2021-06-24T14:12:40Z",
#         "contacts": [
#             {
#                 "name": "Vessey, J Kevin",
#                 "affiliation": "Saint Mary's University"
#             }
#         ],
#         "authors": [
#             "Vessey, J Kevin"
#         ]
#     },
#     {
#         "name": "Tree inventory of UBC Farm to accelerate agroforestry research",
#         "type": "dataset",
#         "url": "https://doi.org/10.5683/SP2/TTQTSH",
#         "global_id": "doi:10.5683/SP2/TTQTSH",
#         "description": "Juxtaposed with the agricultural production systems at the UBC Farm is a large area of second growth forest that is currently classified as an area for agroforestry. While this forest is not currently actively managed for agroforestry or forestry production, it provides an unparalleled resource on campus for research and learning. The objective is to undertake a 100% inventory of all trees >10cm diameter at breast height (DBH), identify and record them in an UBC campus-wide database format, and share the data on an open-source platform for students and researchers at UBC to access. This will provide the necessary baseline for further research on urban forestry, ecosystem services, biodiversity, climate change, potential sustainable timber production, and agroforestry, among others, to take place at UBC Farm. It represents an essential tool for the future sustainable management of the remaining forest on the UBC Farm.",
#         "published_at": "2021-08-24T17:03:09Z",
#         "publisher": "Centre for Sustainable Food Systems at UBC Farm Dataverse",
#         "citationHtml": "Sunderland, Terry; Borah, Joli, 2021, \"Tree inventory of UBC Farm to accelerate agroforestry research\", <a href=\"https://doi.org/10.5683/SP2/TTQTSH\" target=\"_blank\">https://doi.org/10.5683/SP2/TTQTSH</a>, Scholars Portal Dataverse, V3, UNF:6:snp/w/Jfji/qQTuhBVXCZA== [fileUNF]",
#         "identifier_of_dataverse": "UBC_CSFS",
#         "name_of_dataverse": "Centre for Sustainable Food Systems at UBC Farm Dataverse",
#         "citation": "Sunderland, Terry; Borah, Joli, 2021, \"Tree inventory of UBC Farm to accelerate agroforestry research\", https://doi.org/10.5683/SP2/TTQTSH, Scholars Portal Dataverse, V3, UNF:6:snp/w/Jfji/qQTuhBVXCZA== [fileUNF]",
#         "storageIdentifier": "s3://10.5683/SP2/TTQTSH",
#         "keywords": [
#             "Tree Inventory; Agroforestry Research; UBC Farm; Second Growth Forest; Urban Forestry; Future Sustainable Management"
#         ],
#         "subjects": [
#             "Earth and Environmental Sciences",
#             "Agricultural Sciences"
#         ],
#         "fileCount": 3,
#         "versionId": 21920,
#         "versionState": "RELEASED",
#         "majorVersion": 3,
#         "minorVersion": 1,
#         "createdAt": "2021-07-06T00:12:26Z",
#         "updatedAt": "2022-01-24T19:32:42Z",
#         "contacts": [
#             {
#                 "name": "Sunderland, Terry",
#                 "affiliation": "University of British Columbia"
#             }
#         ],
#         "publications": [
#             {
#                 "citation": "Tableau Visualisation",
#                 "url": "https://public.tableau.com/app/profile/ubc.farm/viz/UBCFarmForestInventory/ProjectInformation"
#             },
#             {
#                 "citation": "i-Tree Ecosystem Analysis Report",
#                 "url": "https://lfs-ubcfarm-clone-2018.sites.olt.ubc.ca/files/2021/12/i-Tree-Report_Sunderland-Lab_Aug-18-2021.pdf"
#             }
#         ],
#         "geographicCoverage": [
#             {
#                 "country": ""
#             }
#         ],
#         "authors": [
#             "Sunderland, Terry",
#             "Borah, Joli"
#         ]
#     },
#     {
#         "name": "Comparing the Level of Above-ground Carbon Sequestration and Respective Ecosystem Services between Native and Cultivated Trees in the University of British Columbia Botanical Garden",
#         "type": "dataset",
#         "url": "https://doi.org/10.5683/SP3/L1PQVR",
#         "global_id": "doi:10.5683/SP3/L1PQVR",
#         "description": "Urban trees play an essential role in alleviating the local effects of global warming by sequestering atmospheric carbon dioxide, regulating temperature and reducing air pollution in urban areas. There have been studies estimating carbon sequestration of urban trees using Light Detection and Ranging (LiDAR). Yet, neither of the studies made comparison between species nor extended the discussion towards ecosystem services. Therefore, this study compared the attributes between native and cultivated trees in the Asian Garden of the University of British Columbia (UBC) Botanical Garden, estimated their level of above-ground carbon sequestration, and thus examined respective implications in terms of ecosystem services. A canopy height model was first generated from LiDAR point cloud data for individual tree segmentation based on Dalponte algorithm. There were 803 derived trees matched successfully with the field-measured trees in ArcGIS with an accuracy of 69.5%. The level of above-ground carbon sequestration of each tree was estimated from tree height and canopy area using a non-linear regression model. Results showed that the average carbon sequestration level of native trees was higher than cultivated trees by 1102 kg (p = 3.045 x 10-7), which facilitated more effective soil formation. The average canopy areas of both trees were approximately 63 m2 (p = 0.696), which gives rise to their similar contribution in temperature cooling and air purification. In general, the garden provides a high level of biodiversity and education value thanks to its high species diversity. Regarding future directions in garden management, the removal of native trees and the planting location of cultivated trees in the garden should be carefully evaluated since they have higher level of ecosystem services and higher crown area to height ratio respectively.",
#         "published_at": "2022-04-19T20:43:06Z",
#         "publisher": "Master of Geomatics for Environmental Management",
#         "citationHtml": "Lau, Tsz Him, 2022, \"Comparing the Level of Above-ground Carbon Sequestration and Respective Ecosystem Services between Native and Cultivated Trees in the University of British Columbia Botanical Garden\", <a href=\"https://doi.org/10.5683/SP3/L1PQVR\" target=\"_blank\">https://doi.org/10.5683/SP3/L1PQVR</a>, Scholars Portal Dataverse, V1",
#         "identifier_of_dataverse": "UBC_MGEM",
#         "name_of_dataverse": "Master of Geomatics for Environmental Management",
#         "citation": "Lau, Tsz Him, 2022, \"Comparing the Level of Above-ground Carbon Sequestration and Respective Ecosystem Services between Native and Cultivated Trees in the University of British Columbia Botanical Garden\", https://doi.org/10.5683/SP3/L1PQVR, Scholars Portal Dataverse, V1",
#         "storageIdentifier": "s3://10.5683/SP3/L1PQVR",
#         "keywords": [
#             "above-ground carbon sequestration",
#             "botanical garden",
#             "ecosystem services",
#             "individual tree segmentation",
#             "LiDAR",
#             "urban forestry"
#         ],
#         "subjects": [
#             "Earth and Environmental Sciences",
#             "Computer and Information Science"
#         ],
#         "fileCount": 7,
#         "versionId": 22816,
#         "versionState": "RELEASED",
#         "majorVersion": 1,
#         "minorVersion": 0,
#         "createdAt": "2022-04-08T20:31:55Z",
#         "updatedAt": "2022-04-19T20:43:06Z",
#         "contacts": [
#             {
#                 "name": "Lau, Tsz Him",
#                 "affiliation": "University of British Columbia"
#             }
#         ],
#         "geographicCoverage": [
#             {
#                 "country": "Canada",
#                 "state": "British Columbia,",
#                 "city": "Vancouver,"
#             }
#         ],
#         "authors": [
#             "Lau, Tsz Him"
#         ]
#     }
# ]

# %% [markdown]
# You can see the same results in your browser at https://dataverse.scholarsportal.info/api/search?q=trees&per_page=5. Python simply gives us a way to chain together ("concatenate") different parameters together into a search string that Dataverse understands, then store the response so we can do things with it later.
#
# If you're using Chrome, you can download the [JSON Formatter extension](https://chrome.google.com/webstore/detail/json-formatter/bcjindcccaagfpapjjmafapmmgkkhgoa/related?hl=en) to see a prettier version of the json response.

# %% [markdown]
# ### Try it Yourself
#
# There are many other search parameters we can use. The full list is available on the [Search API](https://guides.dataverse.org/en/latest/api/search.html) page. To test your understanding, here is a list of searches that you can execute with Python.
#
# Using the search API as a reference, try editing the parameters in the code block below and then rerunning it to see the results. The first is done for you as an example.
#
# 1. Datasets with the keyword "climate" and a subject of Arts and Humanities, sorted alphabetically by title.
# 2. Results with a keyword term of Cheese Factories by Army Survey Establishment (author). (**Hint**: Adding `'show_facets': 'true'` to a request will help you see what filters (`fq`) are possible.)
# 3. All tabular data files (\*.tab) uploaded between 2020 and 2022 to the [UVic Research Data Collection](https://dataverse.scholarsportal.info/dataverse/uvic-research), sorted reverse chronologically (i.e. most recent first). (**Hint**: You'll need the `subtree` parameter.)

# %%
search_params = {
    'q': 'climate',
    'type': 'dataset',
    'sort': 'name',
    'order': 'asc',
    'fq': 'subject_ss:"Arts and Humanities"' # Note the double quotes around "Arts and Humanities"
}

resp = requests.get(search_url, params=search_params)
print(resp.url)
results = resp.json()['data']['items']
print(json.dumps(results, indent=2))
# Out:
# https://dataverse.scholarsportal.info/api/search?q=climate&type=dataset&sort=name&order=asc&fq=subject_ss%3A%22Arts+and+Humanities%22
# [
#   {
#     "name": "#climatemarch tweets April 19-May 3, 2017",
#     "type": "dataset",
#     "url": "https://doi.org/10.5683/SP/KZZVZW",
#     "global_id": "doi:10.5683/SP/KZZVZW",
#     "description": "681,668 tweet ids for #climate collected with Documenting the Now's twarc from January 22-26, 2017. Tweets can be \u201crehydrated\u201d with Documenting the Now\u2019s twarc (https://github.com/DocNow/twarc). twarc.py hydrate climatemarch_tweet_ids.txt > climatemarch.json.",
#     "published_at": "2017-05-04T02:18:51Z",
#     "publisher": "Web Archives for Historical Research Group Dataverse",
#     "citationHtml": "Ruest, Nick, 2017, \"#climatemarch tweets April 19-May 3, 2017\", <a href=\"https://doi.org/10.5683/SP/KZZVZW\" target=\"_blank\">https://doi.org/10.5683/SP/KZZVZW</a>, Scholars Portal Dataverse, V1",
#     "identifier_of_dataverse": "wahr",
#     "name_of_dataverse": "Web Archives for Historical Research Group Dataverse",
#     "citation": "Ruest, Nick, 2017, \"#climatemarch tweets April 19-May 3, 2017\", https://doi.org/10.5683/SP/KZZVZW, Scholars Portal Dataverse, V1",
#     "storageIdentifier": "s3://10.5683/SP/KZZVZW",
#     "keywords": [
#       "climatemarch",
#       "politics",
#       "twitter"
#     ],
#     "subjects": [
#       "Social Sciences",
#       "Arts and Humanities"
#     ],
#     "fileCount": 3,
#     "versionId": 3009,
#     "versionState": "RELEASED",
#     "majorVersion": 1,
#     "minorVersion": 0,
#     "createdAt": "2017-05-04T02:16:05Z",
#     "updatedAt": "2017-05-04T02:18:51Z",
#     "contacts": [
#       {
#         "name": "Ruest, Nick",
#         "affiliation": "York University"
#       }
#     ],
#     "authors": [
#       "Ruest, Nick"
#     ]
#   },
#   {
#     "name": "Alberta Survey, 2006",
#     "type": "dataset",
#     "url": "https://doi.org/10.7939/DVN/10550",
#     "global_id": "doi:10.7939/DVN/10550",
#     "description": "The 2006 Alberta Survey (AS) was the 18th annual provincial survey administered by the Population Research Laboratory (PRL). This omnibus survey of households in the province of Alberta continues to enable academic researchers, government departments, and non-profit organizations to explore a wide rang e of research topics in a structured research framework and environment.",
#     "published_at": "2016-01-18T00:00:00Z",
#     "publisher": "Alberta Survey",
#     "citationHtml": "Population Research Laboratory, 2015, \"Alberta Survey, 2006\", <a href=\"https://doi.org/10.7939/DVN/10550\" target=\"_blank\">https://doi.org/10.7939/DVN/10550</a>, Scholars Portal Dataverse, V6",
#     "identifier_of_dataverse": "DL",
#     "name_of_dataverse": "Alberta Survey",
#     "citation": "Population Research Laboratory, 2015, \"Alberta Survey, 2006\", https://doi.org/10.7939/DVN/10550, Scholars Portal Dataverse, V6",
#     "storageIdentifier": "s3://10.7939/DVN/10550",
#     "keywords": [
#       "demographics",
#       "climate change",
#       "AADAC",
#       "neuropathic pain",
#       "forensic science",
#       "physical activity",
#       "genomic research"
#     ],
#     "subjects": [
#       "Social Sciences",
#       "Arts and Humanities"
#     ],
#     "fileCount": 3,
#     "versionId": 13999,
#     "versionState": "RELEASED",
#     "majorVersion": 6,
#     "minorVersion": 1,
#     "createdAt": "2015-09-03T19:47:39Z",
#     "updatedAt": "2018-03-02T18:13:00Z",
#     "contacts": [
#       {
#         "name": "Digital Initiatives",
#         "affiliation": "University of Alberta"
#       }
#     ],
#     "producers": [
#       "Population Research Laboratory"
#     ],
#     "geographicCoverage": [
#       {
#         "country": "Canada"
#       },
#       {
#         "other": "Alberta,"
#       }
#     ],
#     "authors": [
#       "Population Research Laboratory"
#     ]
#   },
#   {
#     "name": "Alberta Survey, 2008",
#     "type": "dataset",
#     "url": "https://doi.org/10.7939/DVN/10013",
#     "global_id": "doi:10.7939/DVN/10013",
#     "description": "The 2008 Alberta Survey (AS) is the 20th annual provincial survey administered by the Population Research Laboratory (PRL). This omnibus survey of househo lds in the province of Alberta continues to enable academic researchers, government departments, and non-profit organizations to explore a wide range of research topics in a structured research framework and environment. Sponsors' research questions are asked together with demographic questions in a telephone interview of Alberta households.",
#     "published_at": "2015-11-04T00:00:00Z",
#     "publisher": "Alberta Survey",
#     "citationHtml": "Population Research Laboratory, 2014, \"Alberta Survey, 2008\", <a href=\"https://doi.org/10.7939/DVN/10013\" target=\"_blank\">https://doi.org/10.7939/DVN/10013</a>, Scholars Portal Dataverse, V6",
#     "identifier_of_dataverse": "DL",
#     "name_of_dataverse": "Alberta Survey",
#     "citation": "Population Research Laboratory, 2014, \"Alberta Survey, 2008\", https://doi.org/10.7939/DVN/10013, Scholars Portal Dataverse, V6",
#     "storageIdentifier": "s3://10.7939/DVN/10013",
#     "keywords": [
#       "demographics",
#       "voting behaviour",
#       "physical activities",
#       "nanotechnology",
#       "AADAC",
#       "genetic testing",
#       "teenage risk behaviour",
#       "avian flu",
#       "climate change",
#       "youth participation in the labour market"
#     ],
#     "subjects": [
#       "Social Sciences",
#       "Arts and Humanities"
#     ],
#     "fileCount": 3,
#     "versionId": 13966,
#     "versionState": "RELEASED",
#     "majorVersion": 6,
#     "minorVersion": 1,
#     "createdAt": "2014-04-25T19:28:18Z",
#     "updatedAt": "2018-03-02T18:36:32Z",
#     "contacts": [
#       {
#         "name": "Digital Initiatives",
#         "affiliation": "University of Alberta Libraries"
#       }
#     ],
#     "producers": [
#       "Population Research Laboratory"
#     ],
#     "geographicCoverage": [
#       {
#         "country": "Canada"
#       },
#       {
#         "other": "Alberta,"
#       }
#     ],
#     "authors": [
#       "Population Research Laboratory"
#     ]
#   },
#   {
#     "name": "Alberta Survey, 2013",
#     "type": "dataset",
#     "url": "https://doi.org/10.7939/DVN/10573",
#     "global_id": "doi:10.7939/DVN/10573",
#     "description": "The Population Research Laboratory (PRL) administered the 2013 Alberta Survey. This survey of households across the province of Alberta continues to enable academic researchers, government departments, and non-profit organizations to explore a wide range of topics in a structured research framework and environment. Sponsors\u2019 research questions are asked together with demographic questions in a telephone interview of Alberta households.",
#     "published_at": "2016-01-18T00:00:00Z",
#     "publisher": "Alberta Survey",
#     "citationHtml": "Population Research Laboratory, 2015, \"Alberta Survey, 2013\", <a href=\"https://doi.org/10.7939/DVN/10573\" target=\"_blank\">https://doi.org/10.7939/DVN/10573</a>, Scholars Portal Dataverse, V3",
#     "identifier_of_dataverse": "DL",
#     "name_of_dataverse": "Alberta Survey",
#     "citation": "Population Research Laboratory, 2015, \"Alberta Survey, 2013\", https://doi.org/10.7939/DVN/10573, Scholars Portal Dataverse, V3",
#     "storageIdentifier": "s3://10.7939/DVN/10573",
#     "keywords": [
#       "socio-demographics",
#       "climate change",
#       "China",
#       "Alberta economy",
#       "financial institutions",
#       "debt",
#       "life experiences",
#       "health",
#       "Temporary Foreign Workers",
#       "public health",
#       "injuries",
#       "alcohol use"
#     ],
#     "subjects": [
#       "Social Sciences",
#       "Arts and Humanities"
#     ],
#     "fileCount": 3,
#     "versionId": 14142,
#     "versionState": "RELEASED",
#     "majorVersion": 3,
#     "minorVersion": 1,
#     "createdAt": "2015-09-09T19:50:57Z",
#     "updatedAt": "2018-03-02T23:29:57Z",
#     "contacts": [
#       {
#         "name": "Digital Initiatives",
#         "affiliation": "University of Alberta"
#       }
#     ],
#     "producers": [
#       "Population Research Laboratory"
#     ],
#     "geographicCoverage": [
#       {
#         "country": "Canada"
#       },
#       {
#         "other": "Alberta,"
#       }
#     ],
#     "authors": [
#       "Population Research Laboratory"
#     ]
#   },
#   {
#     "name": "CC Group 7: Climate Change and Social Media ",
#     "type": "dataset",
#     "url": "https://doi.org/10.5683/SP/WFV7HY",
#     "global_id": "doi:10.5683/SP/WFV7HY",
#     "description": "Provided within this dataset is a research notebook, data, and audio files that were generated as part of a third-year Integrated Science project regarding the communication of climate change science on social media. This research was done to ascertain whether the transition from traditional news mediums to social news mediums has the potential to thin the divide between the scientific consensus on climate change and the public's perception of climate change science. Primary data was collected form the social media platform, Twitter, and a literature review was performed to answer this research question. The primary research revealed where influence resides on Twitter while the literature review incorporated psychological factors, factors related to social media algorithms, and the influence of journalistic norms.",
#     "published_at": "2017-12-09T01:46:01Z",
#     "publisher": "iSci3A12 - Climate Change",
#     "citationHtml": "AlShenaiber, Leena; Houpt, Noah; Tam, Audrey; Fraschetti, Ariana, 2017, \"CC Group 7: Climate Change and Social Media\", <a href=\"https://doi.org/10.5683/SP/WFV7HY\" target=\"_blank\">https://doi.org/10.5683/SP/WFV7HY</a>, Scholars Portal Dataverse, V1, UNF:6:NG/YVGYNvHPtQ+s3tgSaqw== [fileUNF]",
#     "identifier_of_dataverse": "isci3A12-cc",
#     "name_of_dataverse": "iSci3A12 - Climate Change",
#     "citation": "AlShenaiber, Leena; Houpt, Noah; Tam, Audrey; Fraschetti, Ariana, 2017, \"CC Group 7: Climate Change and Social Media\", https://doi.org/10.5683/SP/WFV7HY, Scholars Portal Dataverse, V1, UNF:6:NG/YVGYNvHPtQ+s3tgSaqw== [fileUNF]",
#     "storageIdentifier": "s3://10.5683/SP/WFV7HY",
#     "keywords": [
#       "Climate Change",
#       "Social Media ",
#       "Twitter",
#       "YouTube",
#       "Psychology ",
#       "Journalism ",
#       "Algorithms"
#     ],
#     "subjects": [
#       "Earth and Environmental Sciences",
#       "Social Sciences",
#       "Computer and Information Science",
#       "Arts and Humanities"
#     ],
#     "fileCount": 7,
#     "versionId": 3368,
#     "versionState": "RELEASED",
#     "majorVersion": 1,
#     "minorVersion": 0,
#     "createdAt": "2017-12-07T01:01:53Z",
#     "updatedAt": "2017-12-09T01:46:01Z",
#     "contacts": [
#       {
#         "name": "AlShenaiber, Leena",
#         "affiliation": "McMaster University"
#       }
#     ],
#     "authors": [
#       "AlShenaiber, Leena",
#       "Houpt, Noah",
#       "Tam, Audrey",
#       "Fraschetti, Ariana "
#     ]
#   },
#   {
#     "name": "Silver Spring's Barn 2 - Integrated Project Dossier (2019)",
#     "type": "dataset",
#     "url": "https://doi.org/10.5683/SP2/LFZAOR",
#     "global_id": "doi:10.5683/SP2/LFZAOR",
#     "description": "The Silver Spring Barn 2 was built in 1867 in the Ottawa Valley\u2019s region which was known for its rich soils. It was owned by the Bearman Brothers which were second generation Irish settlers. It is currently used as a residence and workplace program for the mentally and physically disabled by the Association for persons with Developmental Disabilities. The farm now produces 40 000 garlic cloves a year. It has been recognized as a federal heritage building since September 28, 1989 and is the only designated National Capital Commission (NCC) barn in the Greenbelt. The sale of spring water is done at the farm as well. In 1989 the farm was deemed a Recognized Federal Heritage Building. The barn was built with the same scientific designs used for farm buildings at the time. Due to many of these buildings falling apart or being torn down for modern barns, the ones on Silver Springs Farm have not only lasted all these years but are also still functioning. While the barn has undergone restoration, the original foundation and materials used during its construction still remain, keeping the structural and aesthetic properties that make the barn an important example of 19th Century rural architecture. Alongside the barns historic value is its architectural value that helped make it a heritage building. From the layout of the barn to the materials put into it, everything was thought out, intentionally or not, to present the structure as a unified whole. By laying out the different barns into one shaped as a \u201cU\u201d, is a design aspect used to adapt to the changing extremes of Canada\u2019s climate condition. In recent years, Ontario\u2019s Greenbelt has been under threat. The Greenbelt helps prevent urban sprawl from getting out of hand as well as gives Ontarians access to local food and water. While Silver Springs Farm is just one of many in the Greenbelt, it plays a vital role in the community. The farmland keeps urban areas from expanding, gives back to the community with its program for Ottawa and District Association for Persons with Developmental Disabilities and grows then sells garlic right on the farm. This is the Integrated Project Dossier compiled by a group of undergraduate students of the Architectural Conservation and Sustainability Program (Engineers and architects) at Carleton University for the CIVE3207 (ARCN4100) Historic Site Recording and Assessment course in 2019.",
#     "published_at": "2020-07-12T01:53:26Z",
#     "publisher": "Architectural Conservation ",
#     "citationHtml": "Santana Quintero, Mario; Quibell, Taylor; El-Haraki, Sami; Miller, Rowan; Urgolo, Adriano; Thomas, Nigel, 2020, \"Silver Spring's Barn 2 - Integrated Project Dossier (2019)\", <a href=\"https://doi.org/10.5683/SP2/LFZAOR\" target=\"_blank\">https://doi.org/10.5683/SP2/LFZAOR</a>, Scholars Portal Dataverse, V1",
#     "identifier_of_dataverse": "ArchDocCon",
#     "name_of_dataverse": "Architectural Conservation ",
#     "citation": "Santana Quintero, Mario; Quibell, Taylor; El-Haraki, Sami; Miller, Rowan; Urgolo, Adriano; Thomas, Nigel, 2020, \"Silver Spring's Barn 2 - Integrated Project Dossier (2019)\", https://doi.org/10.5683/SP2/LFZAOR, Scholars Portal Dataverse, V1",
#     "storageIdentifier": "s3://10.5683/SP2/LFZAOR",
#     "keywords": [
#       "National capital Commission",
#       "Historic Building",
#       "Heritage Building",
#       "Ottawa",
#       "Farm"
#     ],
#     "subjects": [
#       "Other",
#       "Social Sciences",
#       "Engineering",
#       "Arts and Humanities"
#     ],
#     "fileCount": 39,
#     "versionId": 7348,
#     "versionState": "RELEASED",
#     "majorVersion": 1,
#     "minorVersion": 0,
#     "createdAt": "2020-07-10T13:34:17Z",
#     "updatedAt": "2020-07-12T01:53:26Z",
#     "contacts": [
#       {
#         "name": "Santana Quintero, Mario",
#         "affiliation": "Carleton University"
#       }
#     ],
#     "geographicCoverage": [
#       {
#         "country": "Canada",
#         "state": "Ontario,",
#         "city": "Ottawa,",
#         "other": "1701 Richmond Rd, Nepean, ON K2H 8G4,"
#       }
#     ],
#     "authors": [
#       "Santana Quintero, Mario",
#       "Quibell, Taylor",
#       "El-Haraki, Sami",
#       "Miller, Rowan",
#       "Urgolo, Adriano",
#       "Thomas, Nigel"
#     ]
#   },
#   {
#     "name": "Tyendinaga tweet ids",
#     "type": "dataset",
#     "url": "https://doi.org/10.5683/SP2/FQR2CK",
#     "global_id": "doi:10.5683/SP2/FQR2CK",
#     "description": "80,264 tweet ids for Tyendinaga tweets, collected with Documenting the Now's twarc. Tweets can be \u201crehydrated\u201d with Documenting the Now\u2019s twarc, or Hydrator. twarc hydrate tyendinaga-20210115-ids.txt > tyendinaga.jsonl. Tweets were collected via the Standard Search API on a cron job every five days beginning on February 24, 2020. Collection is ongoing. The account that was used to collect these Tweets failed to collect Tweets for the period from Sun Jul 26 03:46:41 +0000 2020 through Fri Aug 07 20:33:27 +0000 2020.",
#     "published_at": "2021-01-15T14:58:40Z",
#     "publisher": "Web Archives for Historical Research Group Dataverse",
#     "citationHtml": "Ruest, Nick, 2020, \"Tyendinaga tweet ids\", <a href=\"https://doi.org/10.5683/SP2/FQR2CK\" target=\"_blank\">https://doi.org/10.5683/SP2/FQR2CK</a>, Scholars Portal Dataverse, V2",
#     "identifier_of_dataverse": "wahr",
#     "name_of_dataverse": "Web Archives for Historical Research Group Dataverse",
#     "citation": "Ruest, Nick, 2020, \"Tyendinaga tweet ids\", https://doi.org/10.5683/SP2/FQR2CK, Scholars Portal Dataverse, V2",
#     "storageIdentifier": "s3://10.5683/SP2/FQR2CK",
#     "keywords": [
#       "Climate change",
#       "Climate action",
#       "First Nations",
#       "Indigenious land",
#       "Tyendinaga",
#       "Wet'suwet'en",
#       "Coastal GasLink",
#       "2020 Canadian pipeline and railway protests",
#       "Wet'suwet'en opposition",
#       "Solidarity protests",
#       "\u200eRail disruptions"
#     ],
#     "subjects": [
#       "Social Sciences",
#       "Law",
#       "Earth and Environmental Sciences",
#       "Computer and Information Science",
#       "Arts and Humanities"
#     ],
#     "fileCount": 2,
#     "versionId": 8617,
#     "versionState": "RELEASED",
#     "majorVersion": 2,
#     "minorVersion": 0,
#     "createdAt": "2020-04-19T13:26:13Z",
#     "updatedAt": "2021-01-15T14:58:40Z",
#     "contacts": [
#       {
#         "name": "Ruest, Nick",
#         "affiliation": "York University"
#       }
#     ],
#     "publications": [
#       {}
#     ],
#     "geographicCoverage": [
#       {
#         "country": ""
#       }
#     ],
#     "authors": [
#       "Ruest, Nick"
#     ]
#   },
#   {
#     "name": "Wet'suwet'en tweet ids",
#     "type": "dataset",
#     "url": "https://doi.org/10.5683/SP2/C0KFTF",
#     "global_id": "doi:10.5683/SP2/C0KFTF",
#     "description": "425,227 tweet ids for Wet'suwet'en tweets, collected with Documenting the Now's twarc. Tweets can be \u201crehydrated\u201d with Documenting the Now\u2019s twarc, or Hydrator. twarc hydrate wetsuweten-20210115-ids.txt > wetsuweten.jsonl Tweets were collected via the Standard Search API on a cron job every five days beginning on February 18, 2020. Collection is ongoing. The account that was used to collect these Tweets failed to collect Tweets for the period from Sun Jul 26 02:00:21 +0000 2020 through Fri Aug 07 20:05:54 +0000 2020.",
#     "published_at": "2021-01-15T14:49:21Z",
#     "publisher": "Web Archives for Historical Research Group Dataverse",
#     "citationHtml": "Ruest, Nick, 2020, \"Wet'suwet'en tweet ids\", <a href=\"https://doi.org/10.5683/SP2/C0KFTF\" target=\"_blank\">https://doi.org/10.5683/SP2/C0KFTF</a>, Scholars Portal Dataverse, V2",
#     "identifier_of_dataverse": "wahr",
#     "name_of_dataverse": "Web Archives for Historical Research Group Dataverse",
#     "citation": "Ruest, Nick, 2020, \"Wet'suwet'en tweet ids\", https://doi.org/10.5683/SP2/C0KFTF, Scholars Portal Dataverse, V2",
#     "storageIdentifier": "s3://10.5683/SP2/C0KFTF",
#     "keywords": [
#       "Wet'suwet'en opposition",
#       "Climate change",
#       "Climate action",
#       "First Nations",
#       "Indigenious land",
#       "Wet'suwet'en",
#       "Coastal GasLink",
#       "2020 Canadian pipeline and railway protests",
#       "Unceded Aboriginal territory",
#       "Unist\u2019ot\u2019en"
#     ],
#     "subjects": [
#       "Social Sciences",
#       "Law",
#       "Earth and Environmental Sciences",
#       "Computer and Information Science",
#       "Arts and Humanities"
#     ],
#     "fileCount": 2,
#     "versionId": 8616,
#     "versionState": "RELEASED",
#     "majorVersion": 2,
#     "minorVersion": 0,
#     "createdAt": "2020-04-19T13:33:10Z",
#     "updatedAt": "2021-01-15T14:49:21Z",
#     "contacts": [
#       {
#         "name": "Ruest, Nick",
#         "affiliation": "York University"
#       }
#     ],
#     "authors": [
#       "Ruest, Nick"
#     ]
#   }
# ]

# %% [markdown]
# ## Working with Download Statistics (Metrics API)
#
# Let's generate a graph of the top 5 most downloaded datasets in the University of Victoria (UVic) Dataverse, using Dataverse's documentation on [the Metrics API](https://guides.dataverse.org/en/latest/api/metrics.html) for reference.
#
# According to the docs, we can use the url [/api/info/metrics/uniquedownloads](https://dataverse.scholarsportal.info/api/info/metrics/uniquedownloads) to get the number of unique downloads:
#
# >The use case for this metric (uniquedownloads) is to more fairly assess which datasets are getting downloaded/used by only counting each users who downloads any file from a dataset as one count (versus downloads of multiple files or repeat downloads counting as multiple counts which adds a bias for large datasets and/or use patterns where a file is accessed repeatedly for new analyses)
#
# Scholars Portal seems to work a bit differently than described in the Dataverse documentation. For example, the unique downloads are only available as a CSV attachment/file (i.e. not JSON). The [/api/info/metrics/filedownloads](https://dataverse.scholarsportal.info/api/info/metrics/filedownloads) URL returns an empty string so we can't use that either.
#
# Here is the pseudocode (a plain-language recipe or list of steps) for the code that will generate the graph:
# 1. **Download the CSV with download statistics.** The CSV two columns: 1 with the dataset's persistent identifier (PID), 1 with the number of downloads (expressed as an integer or whole number).
# 2. **Use the PID to get the title of the dataset (by making a request to the API).**
# 3. **Generate a simple bar graph with this information.**

# %%
# Get and print the CSV from the Metrics API
dataverse_alias = 'uvic'
text_response = requests.get(f'https://dataverse.scholarsportal.info/api/info/metrics/uniquedownloads?parentAlias={dataverse_alias}').text
print(text_response)
# Out:
# pid,count
# "doi:10.5683/SP2/GCTYCU",34
# "doi:10.5683/SP2/7UOOVR",33
# "doi:10.5683/SP2/GDIZRV",32
# "doi:10.5683/SP2/AAGZDG",17
# "doi:10.5683/SP3/VEIBVL",17
# "doi:10.5683/SP2/3BI57S",13
# "doi:10.5683/SP2/MRHP4Y",12
# "doi:10.5683/SP2/J1H3U4",11
# "doi:10.5683/SP2/5AMBHV",10
# "doi:10.5683/SP2/OOVOQR",10
# "doi:10.5683/SP2/RQR8LN",8
# "doi:10.5683/SP2/NHAYFN",5
# "doi:10.5683/SP2/8KUABH",5
# "doi:10.5683/SP2/SVALAK",4
# "doi:10.5683/SP2/YXUAIC",4
# "doi:10.5683/SP2/GKJPIQ",4
# "doi:10.5683/SP2/URURKC",4
# "doi:10.5683/SP2/1L8NKY",4
# "doi:10.5683/SP2/D7I7CC",3
# "doi:10.5683/SP2/NTRNB7",3
# "doi:10.5683/SP2/KFIH8X",3
# "doi:10.5683/SP2/RFWOJD",3
# "doi:10.5683/SP2/SPOAWK",3
# "doi:10.5683/SP2/DLGXYO",3
# "doi:10.5683/SP2/5LJYXO",3
# "doi:10.5683/SP2/P58E1E",3
# "doi:10.5683/SP2/3RUIQK",3
# "doi:10.5683/SP2/6BATWK",2
# "doi:10.5683/SP2/TTJNIU",2
# "doi:10.5683/SP2/KS3BLD",2
# "doi:10.5683/SP2/ZXZQNN",2
# "doi:10.5683/SP2/KD94VW",2
# "doi:10.5683/SP2/NBG11U",2
# "doi:10.5683/SP2/FPFKUN",2
# "doi:10.5683/SP2/TZCHKE",2
# "doi:10.5683/SP2/2EGZVX",2
# "doi:10.5683/SP2/4QZBZV",2
# "doi:10.5683/SP2/XTK0LQ",2
# "doi:10.5683/SP2/N5SWPE",2
# "doi:10.5683/SP2/XMA1JW",2
# "doi:10.5683/SP2/WDDDMI",2
# "doi:10.5683/SP2/IROW69",2
# "doi:10.5683/SP2/JV6QRP",2
# "doi:10.5683/SP2/WB8JKO",2
# "doi:10.5683/SP2/TACOUX",2
# "doi:10.5683/SP3/LITL4U",2
# "doi:10.5683/SP3/MZ4XS0",2
# "doi:10.5683/SP3/NPQSLV",2
# "doi:10.5683/SP3/CEYG42",2
# "doi:10.5683/SP3/PQAK7O",2
# "doi:10.5683/SP3/6BN2PB",2
# "doi:10.5683/SP3/LKQCR3",2
# "doi:10.5683/SP2/2ZEUGL",1
# "doi:10.5683/SP2/YFYOLU",1
# "doi:10.5683/SP3/3W6SPK",1
# "doi:10.5683/SP3/SLR3GF",1
# "doi:10.5683/SP2/CYRZHE",1
# "doi:10.5683/SP2/GHWXNE",1
# "doi:10.5683/SP3/QJUNMT",1
# "doi:10.5683/SP2/IZ3JPB",1
# "doi:10.5683/SP2/ZGGYVO",1
# "doi:10.5683/SP3/AOFPUZ",1
# "doi:10.5683/SP2/KRGFTC",1
# "doi:10.5683/SP2/1VWZNC",1
# "doi:10.5683/SP2/3DMXCP",1
# "doi:10.5683/SP3/BH7ZBR",1
# "doi:10.5683/SP3/NFKUGG",1
# "doi:10.5683/SP3/CFPFRH",1
# "doi:10.5683/SP2/LMFDM1",1
# "doi:10.5683/SP3/NSZMKI",1
# "doi:10.5683/SP2/ZUENCK",1
# "doi:10.5683/SP2/LBW22S",1
# "doi:10.5683/SP2/OVAJLD",1
# "doi:10.5683/SP2/VHN1UQ",1
# "doi:10.5683/SP2/FPYIVC",1
# "doi:10.5683/SP3/X1BCWX",1
# "doi:10.5683/SP2/10YQLA",1
# "doi:10.5683/SP3/MLPWZB",1
# "doi:10.5683/SP2/XLIM93",1
# "doi:10.5683/SP2/R6P0M5",1
# "doi:10.5683/SP2/FXHOZM",1
# "doi:10.5683/SP3/MFQH1W",1
# "doi:10.5683/SP2/CA77BB",1
# "doi:10.5683/SP2/F4F1A5",1

# %% [markdown]
# The above script will work with any dataverse. To try it with a different dataverse, go to that dataverse's page and edit the `dataverse_alias` to be whatever follows dataverse/ in the URL. For example, to use the Queen's University Dataverse (https://dataverse.scholarsportal.info/dataverse/queens), edit the `dataverse_alias = 'uvic'` to be `dataverse_alias = 'queens'` instead.
#
# This also works for nested dataverses, e.g. [Ocean Networks Canada](https://dataverse.scholarsportal.info/dataverse/oceannetworkscanada) (`oceannetworkscanada`), which is within the UVic Dataverse.

# %% [markdown]
# ### Advanced: Chaining API calls together
#
# It would be nice to know the titles of the most downloaded datasets as well as the DOIs. Looking at [the documentation](https://guides.dataverse.org/en/latest/api/native-api.html) ("Get JSON Representation of a Dataset"), we can make a second API call to Dataverse to get the title of a dataset, given that we know its DOI or PID.

# %%
# Parse the CSV from above into a dictionary
rows = list(csv.DictReader(text_response.splitlines(), delimiter=','))
headers = ['DOI', '# of downloads','title']
print('{:<22}  {:<5}  {:<20}'.format(*headers))
# Print the first 10 results with their titles
for row in rows[0:10]:
    pid = row['pid']
    # Make a request to find the title
    # See "Get JSON Representation of a Dataset" below)
    # https://guides.dataverse.org/en/latest/api/native-api.html
    params = {"persistentId": f'{pid}' }
    resp = requests.get('https://dataverse.scholarsportal.info/api/datasets/:persistentId/', params).json()
    title = resp['data']['latestVersion']['metadataBlocks']['citation']['fields'][0]['value']
    # Shorten titles if they are 10 words or longer
    if len(title.split(' ')) > 9:
        row['title'] = ' '.join(title.split(' ')[0:9] + ['...'])
    else:
        row['title'] = title
    print('{:<28}  {:<8}  {:<15}'.format(*row.values()))
# Out:
# DOI                     # of downloads  title
# doi:10.5683/SP2/GCTYCU        34        2018 Canadian Physician Survey
# doi:10.5683/SP2/7UOOVR        33        Ten years (2006-2016) of oceanographic temperature, salinity, pressure, density ...
# doi:10.5683/SP2/GDIZRV        32        2017 National Survey of Canadian Nurses: Use of Digital ...
# doi:10.5683/SP2/AAGZDG        17        Identifying deep sea fish from videos of a benthic ...
# doi:10.5683/SP3/VEIBVL        17        University Student Mental Health [Student_Mental_Health_2021-10-10]
# doi:10.5683/SP2/3BI57S        13        2016 National Survey of Community-Based Pharmacists: Use of Digital ...
# doi:10.5683/SP2/MRHP4Y        12        2014 National Survey of Canadian Nurses
# doi:10.5683/SP2/J1H3U4        11        2014 National Survey of Canadian Community Pharmacists: Use of ...
# doi:10.5683/SP2/5AMBHV        10        Six years (2009-2015) of oceanographic temperature, salinity, pressure, density ...
# doi:10.5683/SP2/OOVOQR        10        2014 National Survey of Caregivers

# %% [markdown]
# Note that these results are current as of the time you call the API. So you might get a different result if you run the same script tomorrow!
